# %% [markdown]
# ## Imports

# %%
import os
import time
import glob
import pathlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import boto3

# %% [markdown]
# ## Reading data from S3

# %%
bucket = 'sagemaker-ap-south-1-748276930737'
subfolder = 'BBC News Summary/Summaries'
conn = boto3.client('s3')
contents = conn.list_objects(Bucket=bucket, Prefix=subfolder)['Contents']
for f in contents:
    print(f['Key'])
# Out:
# BBC News Summary/Summaries/business/001.txt
# BBC News Summary/Summaries/business/002.txt
# BBC News Summary/Summaries/business/003.txt
# BBC News Summary/Summaries/business/004.txt
# BBC News Summary/Summaries/business/005.txt
# BBC News Summary/Summaries/business/006.txt
# BBC News Summary/Summaries/business/007.txt
# BBC News Summary/Summaries/business/008.txt
# BBC News Summary/Summaries/business/009.txt
# BBC News Summary/Summaries/business/010.txt
# BBC News Summary/Summaries/business/011.txt
# BBC News Summary/Summaries/business/012.txt
# BBC News Summary/Summaries/business/013.txt
# BBC News Summary/Summaries/business/014.txt
# BBC News Summary/Summaries/business/015.txt
# BBC News Summary/Summaries/business/016.txt
# BBC News Summary/Summaries/business/017.txt
# BBC News Summary/Summaries/business/018.txt
# BBC News Summary/Summaries/business/019.txt
# BBC News Summary/Summaries/business/020.txt
# BBC News Summary/Summaries/business/021.txt
# BBC News Summary/Summaries/business/022.txt
# BBC News Summary/Summaries/business/023.txt
# BBC News Summary/Summaries/business/024.txt
# BBC News Summary/Summaries/business/025.txt
# BBC News Summary/Summaries/business/026.txt
# BBC News Summary/Summaries/business/027.txt
# BBC News Summary/Summaries/business/028.txt
# BBC News Summary/Summaries/business/029.txt
# BBC News Summary/Summaries/business/030.txt
# BBC News Summary/Summaries/business/031.txt
# BBC News Summary/Summaries/business/032.txt
# BBC News Summary/Summaries/business/033.txt
# BBC News Summary/Summaries/business/034.txt
# BBC News Summary/Summaries/business/035.txt
# BBC News Summary/Summaries/business/036.txt
# BBC News Summary/Summaries/business/037.txt
# BBC News Summary/Summaries/business/038.txt
# BBC News Summary/Summaries/business/039.txt
# BBC News Summary/Summaries/business/040.txt
# BBC News Summary/Summaries/business/041.txt
# BBC News Summary/Summaries/business/042.txt
# BBC News Summary/Summaries/business/043.txt
# BBC News Summary/Summaries/business/044.txt
# BBC News Summary/Summaries/business/045.txt
# BBC News Summary/Summaries/business/046.txt
# BBC News Summary/Summaries/business/047.txt
# BBC News Summary/Summaries/business/048.txt
# BBC News Summary/Summaries/business/049.txt
# BBC News Summary/Summaries/business/050.txt
# BBC News Summary/Summaries/business/051.txt
# BBC News Summary/Summaries/business/052.txt
# BBC News Summary/Summaries/business/053.txt
# BBC News Summary/Summaries/business/054.txt
# BBC News Summary/Summaries/business/055.txt
# BBC News Summary/Summaries/business/056.txt
# BBC News Summary/Summaries/business/057.txt
# BBC News Summary/Summaries/business/058.txt
# BBC News Summary/Summaries/business/059.txt
# BBC News Summary/Summaries/business/060.txt
# BBC News Summary/Summaries/business/061.txt
# BBC News Summary/Summaries/business/062.txt
# BBC News Summary/Summaries/business/063.txt
# BBC News Summary/Summaries/business/064.txt
# BBC News Summary/Summaries/business/065.txt
# BBC News Summary/Summaries/business/066.txt
# BBC News Summary/Summaries/business/067.txt
# BBC News Summary/Summaries/business/068.txt
# BBC News Summary/Summaries/business/069.txt
# BBC News Summary/Summaries/business/070.txt
# BBC News Summary/Summaries/business/071.txt
# BBC News Summary/Summaries/business/072.txt
# BBC News Summary/Summaries/business/073.txt
# BBC News Summary/Summaries/business/074.txt
# BBC News Summary/Summaries/business/075.txt
# BBC News Summary/Summaries/business/076.txt
# BBC News Summary/Summaries/business/077.txt
# BBC News Summary/Summaries/business/078.txt
# BBC News Summary/Summaries/business/079.txt
# BBC News Summary/Summaries/business/080.txt
# BBC News Summary/Summaries/business/081.txt
# BBC News Summary/Summaries/business/082.txt
# BBC News Summary/Summaries/business/083.txt
# BBC News Summary/Summaries/business/084.txt
# BBC News Summary/Summaries/business/085.txt
# BBC News Summary/Summaries/business/086.txt
# BBC News Summary/Summaries/business/087.txt
# BBC News Summary/Summaries/business/088.txt
# BBC News Summary/Summaries/business/089.txt
# BBC News Summary/Summaries/business/090.txt
# BBC News Summary/Summaries/business/091.txt
# BBC News Summary/Summaries/business/092.txt
# BBC News Summary/Summaries/business/093.txt
# BBC News Summary/Summaries/business/094.txt
# BBC News Summary/Summaries/business/095.txt
# BBC News Summary/Summaries/business/096.txt
# BBC News Summary/Summaries/business/097.txt
# BBC News Summary/Summaries/business/098.txt
# BBC News Summary/Summaries/business/099.txt
# BBC News Summary/Summaries/business/100.txt
# BBC News Summary/Summaries/business/101.txt
# BBC News Summary/Summaries/business/102.txt
# BBC News Summary/Summaries/business/103.txt
# BBC News Summary/Summaries/business/104.txt
# BBC News Summary/Summaries/business/105.txt
# BBC News Summary/Summaries/business/106.txt
# BBC News Summary/Summaries/business/107.txt
# BBC News Summary/Summaries/business/108.txt
# BBC News Summary/Summaries/business/109.txt
# BBC News Summary/Summaries/business/110.txt
# BBC News Summary/Summaries/business/111.txt
# BBC News Summary/Summaries/business/112.txt
# BBC News Summary/Summaries/business/113.txt
# BBC News Summary/Summaries/business/114.txt
# BBC News Summary/Summaries/business/115.txt
# BBC News Summary/Summaries/business/116.txt
# BBC News Summary/Summaries/business/117.txt
# BBC News Summary/Summaries/business/118.txt
# BBC News Summary/Summaries/business/119.txt
# BBC News Summary/Summaries/business/120.txt
# BBC News Summary/Summaries/business/121.txt
# BBC News Summary/Summaries/business/122.txt
# BBC News Summary/Summaries/business/123.txt
# BBC News Summary/Summaries/business/124.txt
# BBC News Summary/Summaries/business/125.txt
# BBC News Summary/Summaries/business/126.txt
# BBC News Summary/Summaries/business/127.txt
# BBC News Summary/Summaries/business/128.txt
# BBC News Summary/Summaries/business/129.txt
# BBC News Summary/Summaries/business/130.txt
# BBC News Summary/Summaries/business/131.txt
# BBC News Summary/Summaries/business/132.txt
# BBC News Summary/Summaries/business/133.txt
# BBC News Summary/Summaries/business/134.txt
# BBC News Summary/Summaries/business/135.txt
# BBC News Summary/Summaries/business/136.txt
# BBC News Summary/Summaries/business/137.txt
# BBC News Summary/Summaries/business/138.txt
# BBC News Summary/Summaries/business/139.txt
# BBC News Summary/Summaries/business/140.txt
# BBC News Summary/Summaries/business/141.txt
# BBC News Summary/Summaries/business/142.txt
# BBC News Summary/Summaries/business/143.txt
# BBC News Summary/Summaries/business/144.txt
# BBC News Summary/Summaries/business/145.txt
# BBC News Summary/Summaries/business/146.txt
# BBC News Summary/Summaries/business/147.txt
# BBC News Summary/Summaries/business/148.txt
# BBC News Summary/Summaries/business/149.txt
# BBC News Summary/Summaries/business/150.txt
# BBC News Summary/Summaries/business/151.txt
# BBC News Summary/Summaries/business/152.txt
# BBC News Summary/Summaries/business/153.txt
# BBC News Summary/Summaries/business/154.txt
# BBC News Summary/Summaries/business/155.txt
# BBC News Summary/Summaries/business/156.txt
# BBC News Summary/Summaries/business/157.txt
# BBC News Summary/Summaries/business/158.txt
# BBC News Summary/Summaries/business/159.txt
# BBC News Summary/Summaries/business/160.txt
# BBC News Summary/Summaries/business/161.txt
# BBC News Summary/Summaries/business/162.txt
# BBC News Summary/Summaries/business/163.txt
# BBC News Summary/Summaries/business/164.txt
# BBC News Summary/Summaries/business/165.txt
# BBC News Summary/Summaries/business/166.txt
# BBC News Summary/Summaries/business/167.txt
# BBC News Summary/Summaries/business/168.txt
# BBC News Summary/Summaries/business/169.txt
# BBC News Summary/Summaries/business/170.txt
# BBC News Summary/Summaries/business/171.txt
# BBC News Summary/Summaries/business/172.txt
# BBC News Summary/Summaries/business/173.txt
# BBC News Summary/Summaries/business/174.txt
# BBC News Summary/Summaries/business/175.txt
# BBC News Summary/Summaries/business/176.txt
# BBC News Summary/Summaries/business/177.txt
# BBC News Summary/Summaries/business/178.txt
# BBC News Summary/Summaries/business/179.txt
# BBC News Summary/Summaries/business/180.txt
# BBC News Summary/Summaries/business/181.txt
# BBC News Summary/Summaries/business/182.txt
# BBC News Summary/Summaries/business/183.txt
# BBC News Summary/Summaries/business/184.txt
# BBC News Summary/Summaries/business/185.txt
# BBC News Summary/Summaries/business/186.txt
# BBC News Summary/Summaries/business/187.txt
# BBC News Summary/Summaries/business/188.txt
# BBC News Summary/Summaries/business/189.txt
# BBC News Summary/Summaries/business/190.txt
# BBC News Summary/Summaries/business/191.txt
# BBC News Summary/Summaries/business/192.txt
# BBC News Summary/Summaries/business/193.txt
# BBC News Summary/Summaries/business/194.txt
# BBC News Summary/Summaries/business/195.txt
# BBC News Summary/Summaries/business/196.txt
# BBC News Summary/Summaries/business/197.txt
# BBC News Summary/Summaries/business/198.txt
# BBC News Summary/Summaries/business/199.txt
# BBC News Summary/Summaries/business/200.txt
# BBC News Summary/Summaries/business/201.txt
# BBC News Summary/Summaries/business/202.txt
# BBC News Summary/Summaries/business/203.txt
# BBC News Summary/Summaries/business/204.txt
# BBC News Summary/Summaries/business/205.txt
# BBC News Summary/Summaries/business/206.txt
# BBC News Summary/Summaries/business/207.txt
# BBC News Summary/Summaries/business/208.txt
# BBC News Summary/Summaries/business/209.txt
# BBC News Summary/Summaries/business/210.txt
# BBC News Summary/Summaries/business/211.txt
# BBC News Summary/Summaries/business/212.txt
# BBC News Summary/Summaries/business/213.txt
# BBC News Summary/Summaries/business/214.txt
# BBC News Summary/Summaries/business/215.txt
# BBC News Summary/Summaries/business/216.txt
# BBC News Summary/Summaries/business/217.txt
# BBC News Summary/Summaries/business/218.txt
# BBC News Summary/Summaries/business/219.txt
# BBC News Summary/Summaries/business/220.txt
# BBC News Summary/Summaries/business/221.txt
# BBC News Summary/Summaries/business/222.txt
# BBC News Summary/Summaries/business/223.txt
# BBC News Summary/Summaries/business/224.txt
# BBC News Summary/Summaries/business/225.txt
# BBC News Summary/Summaries/business/226.txt
# BBC News Summary/Summaries/business/227.txt
# BBC News Summary/Summaries/business/228.txt
# BBC News Summary/Summaries/business/229.txt
# BBC News Summary/Summaries/business/230.txt
# BBC News Summary/Summaries/business/231.txt
# BBC News Summary/Summaries/business/232.txt
# BBC News Summary/Summaries/business/233.txt
# BBC News Summary/Summaries/business/234.txt
# BBC News Summary/Summaries/business/235.txt
# BBC News Summary/Summaries/business/236.txt
# BBC News Summary/Summaries/business/237.txt
# BBC News Summary/Summaries/business/238.txt
# BBC News Summary/Summaries/business/239.txt
# BBC News Summary/Summaries/business/240.txt
# BBC News Summary/Summaries/business/241.txt
# BBC News Summary/Summaries/business/242.txt
# BBC News Summary/Summaries/business/243.txt
# BBC News Summary/Summaries/business/244.txt
# BBC News Summary/Summaries/business/245.txt
# BBC News Summary/Summaries/business/246.txt
# BBC News Summary/Summaries/business/247.txt
# BBC News Summary/Summaries/business/248.txt
# BBC News Summary/Summaries/business/249.txt
# BBC News Summary/Summaries/business/250.txt
# BBC News Summary/Summaries/business/251.txt
# BBC News Summary/Summaries/business/252.txt
# BBC News Summary/Summaries/business/253.txt
# BBC News Summary/Summaries/business/254.txt
# BBC News Summary/Summaries/business/255.txt
# BBC News Summary/Summaries/business/256.txt
# BBC News Summary/Summaries/business/257.txt
# BBC News Summary/Summaries/business/258.txt
# BBC News Summary/Summaries/business/259.txt
# BBC News Summary/Summaries/business/260.txt
# BBC News Summary/Summaries/business/261.txt
# BBC News Summary/Summaries/business/262.txt
# BBC News Summary/Summaries/business/263.txt
# BBC News Summary/Summaries/business/264.txt
# BBC News Summary/Summaries/business/265.txt
# BBC News Summary/Summaries/business/266.txt
# BBC News Summary/Summaries/business/267.txt
# BBC News Summary/Summaries/business/268.txt
# BBC News Summary/Summaries/business/269.txt
# BBC News Summary/Summaries/business/270.txt
# BBC News Summary/Summaries/business/271.txt
# BBC News Summary/Summaries/business/272.txt
# BBC News Summary/Summaries/business/273.txt
# BBC News Summary/Summaries/business/274.txt
# BBC News Summary/Summaries/business/275.txt
# BBC News Summary/Summaries/business/276.txt
# BBC News Summary/Summaries/business/277.txt
# BBC News Summary/Summaries/business/278.txt
# BBC News Summary/Summaries/business/279.txt
# BBC News Summary/Summaries/business/280.txt
# BBC News Summary/Summaries/business/281.txt
# BBC News Summary/Summaries/business/282.txt
# BBC News Summary/Summaries/business/283.txt
# BBC News Summary/Summaries/business/284.txt
# BBC News Summary/Summaries/business/285.txt
# BBC News Summary/Summaries/business/286.txt
# BBC News Summary/Summaries/business/287.txt
# BBC News Summary/Summaries/business/288.txt
# BBC News Summary/Summaries/business/289.txt
# BBC News Summary/Summaries/business/290.txt
# BBC News Summary/Summaries/business/291.txt
# BBC News Summary/Summaries/business/292.txt
# BBC News Summary/Summaries/business/293.txt
# BBC News Summary/Summaries/business/294.txt
# BBC News Summary/Summaries/business/295.txt
# BBC News Summary/Summaries/business/296.txt
# BBC News Summary/Summaries/business/297.txt
# BBC News Summary/Summaries/business/298.txt
# BBC News Summary/Summaries/business/299.txt
# BBC News Summary/Summaries/business/300.txt
# BBC News Summary/Summaries/business/301.txt
# BBC News Summary/Summaries/business/302.txt
# BBC News Summary/Summaries/business/303.txt
# BBC News Summary/Summaries/business/304.txt
# BBC News Summary/Summaries/business/305.txt
# BBC News Summary/Summaries/business/306.txt
# BBC News Summary/Summaries/business/307.txt
# BBC News Summary/Summaries/business/308.txt
# BBC News Summary/Summaries/business/309.txt
# BBC News Summary/Summaries/business/310.txt
# BBC News Summary/Summaries/business/311.txt
# BBC News Summary/Summaries/business/312.txt
# BBC News Summary/Summaries/business/313.txt
# BBC News Summary/Summaries/business/314.txt
# BBC News Summary/Summaries/business/315.txt
# BBC News Summary/Summaries/business/316.txt
# BBC News Summary/Summaries/business/317.txt
# BBC News Summary/Summaries/business/318.txt
# BBC News Summary/Summaries/business/319.txt
# BBC News Summary/Summaries/business/320.txt
# BBC News Summary/Summaries/business/321.txt
# BBC News Summary/Summaries/business/322.txt
# BBC News Summary/Summaries/business/323.txt
# BBC News Summary/Summaries/business/324.txt
# BBC News Summary/Summaries/business/325.txt
# BBC News Summary/Summaries/business/326.txt
# BBC News Summary/Summaries/business/327.txt
# BBC News Summary/Summaries/business/328.txt
# BBC News Summary/Summaries/business/329.txt
# BBC News Summary/Summaries/business/330.txt
# BBC News Summary/Summaries/business/331.txt
# BBC News Summary/Summaries/business/332.txt
# BBC News Summary/Summaries/business/333.txt
# BBC News Summary/Summaries/business/334.txt
# BBC News Summary/Summaries/business/335.txt
# BBC News Summary/Summaries/business/336.txt
# BBC News Summary/Summaries/business/337.txt
# BBC News Summary/Summaries/business/338.txt
# BBC News Summary/Summaries/business/339.txt
# BBC News Summary/Summaries/business/340.txt
# BBC News Summary/Summaries/business/341.txt
# BBC News Summary/Summaries/business/342.txt
# BBC News Summary/Summaries/business/343.txt
# BBC News Summary/Summaries/business/344.txt
# BBC News Summary/Summaries/business/345.txt
# BBC News Summary/Summaries/business/346.txt
# BBC News Summary/Summaries/business/347.txt
# BBC News Summary/Summaries/business/348.txt
# BBC News Summary/Summaries/business/349.txt
# BBC News Summary/Summaries/business/350.txt
# BBC News Summary/Summaries/business/351.txt
# BBC News Summary/Summaries/business/352.txt
# BBC News Summary/Summaries/business/353.txt
# BBC News Summary/Summaries/business/354.txt
# BBC News Summary/Summaries/business/355.txt
# BBC News Summary/Summaries/business/356.txt
# BBC News Summary/Summaries/business/357.txt
# BBC News Summary/Summaries/business/358.txt
# BBC News Summary/Summaries/business/359.txt
# BBC News Summary/Summaries/business/360.txt
# BBC News Summary/Summaries/business/361.txt
# BBC News Summary/Summaries/business/362.txt
# BBC News Summary/Summaries/business/363.txt
# BBC News Summary/Summaries/business/364.txt
# BBC News Summary/Summaries/business/365.txt
# BBC News Summary/Summaries/business/366.txt
# BBC News Summary/Summaries/business/367.txt
# BBC News Summary/Summaries/business/368.txt
# BBC News Summary/Summaries/business/369.txt
# BBC News Summary/Summaries/business/370.txt
# BBC News Summary/Summaries/business/371.txt
# BBC News Summary/Summaries/business/372.txt
# BBC News Summary/Summaries/business/373.txt
# BBC News Summary/Summaries/business/374.txt
# BBC News Summary/Summaries/business/375.txt
# BBC News Summary/Summaries/business/376.txt
# BBC News Summary/Summaries/business/377.txt
# BBC News Summary/Summaries/business/378.txt
# BBC News Summary/Summaries/business/379.txt
# BBC News Summary/Summaries/business/380.txt
# BBC News Summary/Summaries/business/381.txt
# BBC News Summary/Summaries/business/382.txt
# BBC News Summary/Summaries/business/383.txt
# BBC News Summary/Summaries/business/384.txt
# BBC News Summary/Summaries/business/385.txt
# BBC News Summary/Summaries/business/386.txt
# BBC News Summary/Summaries/business/387.txt
# BBC News Summary/Summaries/business/388.txt
# BBC News Summary/Summaries/business/389.txt
# BBC News Summary/Summaries/business/390.txt
# BBC News Summary/Summaries/business/391.txt
# BBC News Summary/Summaries/business/392.txt
# BBC News Summary/Summaries/business/393.txt
# BBC News Summary/Summaries/business/394.txt
# BBC News Summary/Summaries/business/395.txt
# BBC News Summary/Summaries/business/396.txt
# BBC News Summary/Summaries/business/397.txt
# BBC News Summary/Summaries/business/398.txt
# BBC News Summary/Summaries/business/399.txt
# BBC News Summary/Summaries/business/400.txt
# BBC News Summary/Summaries/business/401.txt
# BBC News Summary/Summaries/business/402.txt
# BBC News Summary/Summaries/business/403.txt
# BBC News Summary/Summaries/business/404.txt
# BBC News Summary/Summaries/business/405.txt
# BBC News Summary/Summaries/business/406.txt
# BBC News Summary/Summaries/business/407.txt
# BBC News Summary/Summaries/business/408.txt
# BBC News Summary/Summaries/business/409.txt
# BBC News Summary/Summaries/business/410.txt
# BBC News Summary/Summaries/business/411.txt
# BBC News Summary/Summaries/business/412.txt
# BBC News Summary/Summaries/business/413.txt
# BBC News Summary/Summaries/business/414.txt
# BBC News Summary/Summaries/business/415.txt
# BBC News Summary/Summaries/business/416.txt
# BBC News Summary/Summaries/business/417.txt
# BBC News Summary/Summaries/business/418.txt
# BBC News Summary/Summaries/business/419.txt
# BBC News Summary/Summaries/business/420.txt
# BBC News Summary/Summaries/business/421.txt
# BBC News Summary/Summaries/business/422.txt
# BBC News Summary/Summaries/business/423.txt
# BBC News Summary/Summaries/business/424.txt
# BBC News Summary/Summaries/business/425.txt
# BBC News Summary/Summaries/business/426.txt
# BBC News Summary/Summaries/business/427.txt
# BBC News Summary/Summaries/business/428.txt
# BBC News Summary/Summaries/business/429.txt
# BBC News Summary/Summaries/business/430.txt
# BBC News Summary/Summaries/business/431.txt
# BBC News Summary/Summaries/business/432.txt
# BBC News Summary/Summaries/business/433.txt
# BBC News Summary/Summaries/business/434.txt
# BBC News Summary/Summaries/business/435.txt
# BBC News Summary/Summaries/business/436.txt
# BBC News Summary/Summaries/business/437.txt
# BBC News Summary/Summaries/business/438.txt
# BBC News Summary/Summaries/business/439.txt
# BBC News Summary/Summaries/business/440.txt
# BBC News Summary/Summaries/business/441.txt
# BBC News Summary/Summaries/business/442.txt
# BBC News Summary/Summaries/business/443.txt
# BBC News Summary/Summaries/business/444.txt
# BBC News Summary/Summaries/business/445.txt
# BBC News Summary/Summaries/business/446.txt
# BBC News Summary/Summaries/business/447.txt
# BBC News Summary/Summaries/business/448.txt
# BBC News Summary/Summaries/business/449.txt
# BBC News Summary/Summaries/business/450.txt
# BBC News Summary/Summaries/business/451.txt
# BBC News Summary/Summaries/business/452.txt
# BBC News Summary/Summaries/business/453.txt
# BBC News Summary/Summaries/business/454.txt
# BBC News Summary/Summaries/business/455.txt
# BBC News Summary/Summaries/business/456.txt
# BBC News Summary/Summaries/business/457.txt
# BBC News Summary/Summaries/business/458.txt
# BBC News Summary/Summaries/business/459.txt
# BBC News Summary/Summaries/business/460.txt
# BBC News Summary/Summaries/business/461.txt
# BBC News Summary/Summaries/business/462.txt
# BBC News Summary/Summaries/business/463.txt
# BBC News Summary/Summaries/business/464.txt
# BBC News Summary/Summaries/business/465.txt
# BBC News Summary/Summaries/business/466.txt
# BBC News Summary/Summaries/business/467.txt
# BBC News Summary/Summaries/business/468.txt
# BBC News Summary/Summaries/business/469.txt
# BBC News Summary/Summaries/business/470.txt
# BBC News Summary/Summaries/business/471.txt
# BBC News Summary/Summaries/business/472.txt
# BBC News Summary/Summaries/business/473.txt
# BBC News Summary/Summaries/business/474.txt
# BBC News Summary/Summaries/business/475.txt
# BBC News Summary/Summaries/business/476.txt
# BBC News Summary/Summaries/business/477.txt
# BBC News Summary/Summaries/business/478.txt
# BBC News Summary/Summaries/business/479.txt
# BBC News Summary/Summaries/business/480.txt
# BBC News Summary/Summaries/business/481.txt
# BBC News Summary/Summaries/business/482.txt
# BBC News Summary/Summaries/business/483.txt
# BBC News Summary/Summaries/business/484.txt
# BBC News Summary/Summaries/business/485.txt
# BBC News Summary/Summaries/business/486.txt
# BBC News Summary/Summaries/business/487.txt
# BBC News Summary/Summaries/business/488.txt
# BBC News Summary/Summaries/business/489.txt
# BBC News Summary/Summaries/business/490.txt
# BBC News Summary/Summaries/business/491.txt
# BBC News Summary/Summaries/business/492.txt
# BBC News Summary/Summaries/business/493.txt
# BBC News Summary/Summaries/business/494.txt
# BBC News Summary/Summaries/business/495.txt
# BBC News Summary/Summaries/business/496.txt
# BBC News Summary/Summaries/business/497.txt
# BBC News Summary/Summaries/business/498.txt
# BBC News Summary/Summaries/business/499.txt
# BBC News Summary/Summaries/business/500.txt
# BBC News Summary/Summaries/business/501.txt
# BBC News Summary/Summaries/business/502.txt
# BBC News Summary/Summaries/business/503.txt
# BBC News Summary/Summaries/business/504.txt
# BBC News Summary/Summaries/business/505.txt
# BBC News Summary/Summaries/business/506.txt
# BBC News Summary/Summaries/business/507.txt
# BBC News Summary/Summaries/business/508.txt
# BBC News Summary/Summaries/business/509.txt
# BBC News Summary/Summaries/business/510.txt
# BBC News Summary/Summaries/entertainment/001.txt
# BBC News Summary/Summaries/entertainment/002.txt
# BBC News Summary/Summaries/entertainment/003.txt
# BBC News Summary/Summaries/entertainment/004.txt
# BBC News Summary/Summaries/entertainment/005.txt
# BBC News Summary/Summaries/entertainment/006.txt
# BBC News Summary/Summaries/entertainment/007.txt
# BBC News Summary/Summaries/entertainment/008.txt
# BBC News Summary/Summaries/entertainment/009.txt
# BBC News Summary/Summaries/entertainment/010.txt
# BBC News Summary/Summaries/entertainment/011.txt
# BBC News Summary/Summaries/entertainment/012.txt
# BBC News Summary/Summaries/entertainment/013.txt
# BBC News Summary/Summaries/entertainment/014.txt
# BBC News Summary/Summaries/entertainment/015.txt
# BBC News Summary/Summaries/entertainment/016.txt
# BBC News Summary/Summaries/entertainment/017.txt
# BBC News Summary/Summaries/entertainment/018.txt
# BBC News Summary/Summaries/entertainment/019.txt
# BBC News Summary/Summaries/entertainment/020.txt
# BBC News Summary/Summaries/entertainment/021.txt
# BBC News Summary/Summaries/entertainment/022.txt
# BBC News Summary/Summaries/entertainment/023.txt
# BBC News Summary/Summaries/entertainment/024.txt
# BBC News Summary/Summaries/entertainment/025.txt
# BBC News Summary/Summaries/entertainment/026.txt
# BBC News Summary/Summaries/entertainment/027.txt
# BBC News Summary/Summaries/entertainment/028.txt
# BBC News Summary/Summaries/entertainment/029.txt
# BBC News Summary/Summaries/entertainment/030.txt
# BBC News Summary/Summaries/entertainment/031.txt
# BBC News Summary/Summaries/entertainment/032.txt
# BBC News Summary/Summaries/entertainment/033.txt
# BBC News Summary/Summaries/entertainment/034.txt
# BBC News Summary/Summaries/entertainment/035.txt
# BBC News Summary/Summaries/entertainment/036.txt
# BBC News Summary/Summaries/entertainment/037.txt
# BBC News Summary/Summaries/entertainment/038.txt
# BBC News Summary/Summaries/entertainment/039.txt
# BBC News Summary/Summaries/entertainment/040.txt
# BBC News Summary/Summaries/entertainment/041.txt
# BBC News Summary/Summaries/entertainment/042.txt
# BBC News Summary/Summaries/entertainment/043.txt
# BBC News Summary/Summaries/entertainment/044.txt
# BBC News Summary/Summaries/entertainment/045.txt
# BBC News Summary/Summaries/entertainment/046.txt
# BBC News Summary/Summaries/entertainment/047.txt
# BBC News Summary/Summaries/entertainment/048.txt
# BBC News Summary/Summaries/entertainment/049.txt
# BBC News Summary/Summaries/entertainment/050.txt
# BBC News Summary/Summaries/entertainment/051.txt
# BBC News Summary/Summaries/entertainment/052.txt
# BBC News Summary/Summaries/entertainment/053.txt
# BBC News Summary/Summaries/entertainment/054.txt
# BBC News Summary/Summaries/entertainment/055.txt
# BBC News Summary/Summaries/entertainment/056.txt
# BBC News Summary/Summaries/entertainment/057.txt
# BBC News Summary/Summaries/entertainment/058.txt
# BBC News Summary/Summaries/entertainment/059.txt
# BBC News Summary/Summaries/entertainment/060.txt
# BBC News Summary/Summaries/entertainment/061.txt
# BBC News Summary/Summaries/entertainment/062.txt
# BBC News Summary/Summaries/entertainment/063.txt
# BBC News Summary/Summaries/entertainment/064.txt
# BBC News Summary/Summaries/entertainment/065.txt
# BBC News Summary/Summaries/entertainment/066.txt
# BBC News Summary/Summaries/entertainment/067.txt
# BBC News Summary/Summaries/entertainment/068.txt
# BBC News Summary/Summaries/entertainment/069.txt
# BBC News Summary/Summaries/entertainment/070.txt
# BBC News Summary/Summaries/entertainment/071.txt
# BBC News Summary/Summaries/entertainment/072.txt
# BBC News Summary/Summaries/entertainment/073.txt
# BBC News Summary/Summaries/entertainment/074.txt
# BBC News Summary/Summaries/entertainment/075.txt
# BBC News Summary/Summaries/entertainment/076.txt
# BBC News Summary/Summaries/entertainment/077.txt
# BBC News Summary/Summaries/entertainment/078.txt
# BBC News Summary/Summaries/entertainment/079.txt
# BBC News Summary/Summaries/entertainment/080.txt
# BBC News Summary/Summaries/entertainment/081.txt
# BBC News Summary/Summaries/entertainment/082.txt
# BBC News Summary/Summaries/entertainment/083.txt
# BBC News Summary/Summaries/entertainment/084.txt
# BBC News Summary/Summaries/entertainment/085.txt
# BBC News Summary/Summaries/entertainment/086.txt
# BBC News Summary/Summaries/entertainment/087.txt
# BBC News Summary/Summaries/entertainment/088.txt
# BBC News Summary/Summaries/entertainment/089.txt
# BBC News Summary/Summaries/entertainment/090.txt
# BBC News Summary/Summaries/entertainment/091.txt
# BBC News Summary/Summaries/entertainment/092.txt
# BBC News Summary/Summaries/entertainment/093.txt
# BBC News Summary/Summaries/entertainment/094.txt
# BBC News Summary/Summaries/entertainment/095.txt
# BBC News Summary/Summaries/entertainment/096.txt
# BBC News Summary/Summaries/entertainment/097.txt
# BBC News Summary/Summaries/entertainment/098.txt
# BBC News Summary/Summaries/entertainment/099.txt
# BBC News Summary/Summaries/entertainment/100.txt
# BBC News Summary/Summaries/entertainment/101.txt
# BBC News Summary/Summaries/entertainment/102.txt
# BBC News Summary/Summaries/entertainment/103.txt
# BBC News Summary/Summaries/entertainment/104.txt
# BBC News Summary/Summaries/entertainment/105.txt
# BBC News Summary/Summaries/entertainment/106.txt
# BBC News Summary/Summaries/entertainment/107.txt
# BBC News Summary/Summaries/entertainment/108.txt
# BBC News Summary/Summaries/entertainment/109.txt
# BBC News Summary/Summaries/entertainment/110.txt
# BBC News Summary/Summaries/entertainment/111.txt
# BBC News Summary/Summaries/entertainment/112.txt
# BBC News Summary/Summaries/entertainment/113.txt
# BBC News Summary/Summaries/entertainment/114.txt
# BBC News Summary/Summaries/entertainment/115.txt
# BBC News Summary/Summaries/entertainment/116.txt
# BBC News Summary/Summaries/entertainment/117.txt
# BBC News Summary/Summaries/entertainment/118.txt
# BBC News Summary/Summaries/entertainment/119.txt
# BBC News Summary/Summaries/entertainment/120.txt
# BBC News Summary/Summaries/entertainment/121.txt
# BBC News Summary/Summaries/entertainment/122.txt
# BBC News Summary/Summaries/entertainment/123.txt
# BBC News Summary/Summaries/entertainment/124.txt
# BBC News Summary/Summaries/entertainment/125.txt
# BBC News Summary/Summaries/entertainment/126.txt
# BBC News Summary/Summaries/entertainment/127.txt
# BBC News Summary/Summaries/entertainment/128.txt
# BBC News Summary/Summaries/entertainment/129.txt
# BBC News Summary/Summaries/entertainment/130.txt
# BBC News Summary/Summaries/entertainment/131.txt
# BBC News Summary/Summaries/entertainment/132.txt
# BBC News Summary/Summaries/entertainment/133.txt
# BBC News Summary/Summaries/entertainment/134.txt
# BBC News Summary/Summaries/entertainment/135.txt
# BBC News Summary/Summaries/entertainment/136.txt
# BBC News Summary/Summaries/entertainment/137.txt
# BBC News Summary/Summaries/entertainment/138.txt
# BBC News Summary/Summaries/entertainment/139.txt
# BBC News Summary/Summaries/entertainment/140.txt
# BBC News Summary/Summaries/entertainment/141.txt
# BBC News Summary/Summaries/entertainment/142.txt
# BBC News Summary/Summaries/entertainment/143.txt
# BBC News Summary/Summaries/entertainment/144.txt
# BBC News Summary/Summaries/entertainment/145.txt
# BBC News Summary/Summaries/entertainment/146.txt
# BBC News Summary/Summaries/entertainment/147.txt
# BBC News Summary/Summaries/entertainment/148.txt
# BBC News Summary/Summaries/entertainment/149.txt
# BBC News Summary/Summaries/entertainment/150.txt
# BBC News Summary/Summaries/entertainment/151.txt
# BBC News Summary/Summaries/entertainment/152.txt
# BBC News Summary/Summaries/entertainment/153.txt
# BBC News Summary/Summaries/entertainment/154.txt
# BBC News Summary/Summaries/entertainment/155.txt
# BBC News Summary/Summaries/entertainment/156.txt
# BBC News Summary/Summaries/entertainment/157.txt
# BBC News Summary/Summaries/entertainment/158.txt
# BBC News Summary/Summaries/entertainment/159.txt
# BBC News Summary/Summaries/entertainment/160.txt
# BBC News Summary/Summaries/entertainment/161.txt
# BBC News Summary/Summaries/entertainment/162.txt
# BBC News Summary/Summaries/entertainment/163.txt
# BBC News Summary/Summaries/entertainment/164.txt
# BBC News Summary/Summaries/entertainment/165.txt
# BBC News Summary/Summaries/entertainment/166.txt
# BBC News Summary/Summaries/entertainment/167.txt
# BBC News Summary/Summaries/entertainment/168.txt
# BBC News Summary/Summaries/entertainment/169.txt
# BBC News Summary/Summaries/entertainment/170.txt
# BBC News Summary/Summaries/entertainment/171.txt
# BBC News Summary/Summaries/entertainment/172.txt
# BBC News Summary/Summaries/entertainment/173.txt
# BBC News Summary/Summaries/entertainment/174.txt
# BBC News Summary/Summaries/entertainment/175.txt
# BBC News Summary/Summaries/entertainment/176.txt
# BBC News Summary/Summaries/entertainment/177.txt
# BBC News Summary/Summaries/entertainment/178.txt
# BBC News Summary/Summaries/entertainment/179.txt
# BBC News Summary/Summaries/entertainment/180.txt
# BBC News Summary/Summaries/entertainment/181.txt
# BBC News Summary/Summaries/entertainment/182.txt
# BBC News Summary/Summaries/entertainment/183.txt
# BBC News Summary/Summaries/entertainment/184.txt
# BBC News Summary/Summaries/entertainment/185.txt
# BBC News Summary/Summaries/entertainment/186.txt
# BBC News Summary/Summaries/entertainment/187.txt
# BBC News Summary/Summaries/entertainment/188.txt
# BBC News Summary/Summaries/entertainment/189.txt
# BBC News Summary/Summaries/entertainment/190.txt
# BBC News Summary/Summaries/entertainment/191.txt
# BBC News Summary/Summaries/entertainment/192.txt
# BBC News Summary/Summaries/entertainment/193.txt
# BBC News Summary/Summaries/entertainment/194.txt
# BBC News Summary/Summaries/entertainment/195.txt
# BBC News Summary/Summaries/entertainment/196.txt
# BBC News Summary/Summaries/entertainment/197.txt
# BBC News Summary/Summaries/entertainment/198.txt
# BBC News Summary/Summaries/entertainment/199.txt
# BBC News Summary/Summaries/entertainment/200.txt
# BBC News Summary/Summaries/entertainment/201.txt
# BBC News Summary/Summaries/entertainment/202.txt
# BBC News Summary/Summaries/entertainment/203.txt
# BBC News Summary/Summaries/entertainment/204.txt
# BBC News Summary/Summaries/entertainment/205.txt
# BBC News Summary/Summaries/entertainment/206.txt
# BBC News Summary/Summaries/entertainment/207.txt
# BBC News Summary/Summaries/entertainment/208.txt
# BBC News Summary/Summaries/entertainment/209.txt
# BBC News Summary/Summaries/entertainment/210.txt
# BBC News Summary/Summaries/entertainment/211.txt
# BBC News Summary/Summaries/entertainment/212.txt
# BBC News Summary/Summaries/entertainment/213.txt
# BBC News Summary/Summaries/entertainment/214.txt
# BBC News Summary/Summaries/entertainment/215.txt
# BBC News Summary/Summaries/entertainment/216.txt
# BBC News Summary/Summaries/entertainment/217.txt
# BBC News Summary/Summaries/entertainment/218.txt
# BBC News Summary/Summaries/entertainment/219.txt
# BBC News Summary/Summaries/entertainment/220.txt
# BBC News Summary/Summaries/entertainment/221.txt
# BBC News Summary/Summaries/entertainment/222.txt
# BBC News Summary/Summaries/entertainment/223.txt
# BBC News Summary/Summaries/entertainment/224.txt
# BBC News Summary/Summaries/entertainment/225.txt
# BBC News Summary/Summaries/entertainment/226.txt
# BBC News Summary/Summaries/entertainment/227.txt
# BBC News Summary/Summaries/entertainment/228.txt
# BBC News Summary/Summaries/entertainment/229.txt
# BBC News Summary/Summaries/entertainment/230.txt
# BBC News Summary/Summaries/entertainment/231.txt
# BBC News Summary/Summaries/entertainment/232.txt
# BBC News Summary/Summaries/entertainment/233.txt
# BBC News Summary/Summaries/entertainment/234.txt
# BBC News Summary/Summaries/entertainment/235.txt
# BBC News Summary/Summaries/entertainment/236.txt
# BBC News Summary/Summaries/entertainment/237.txt
# BBC News Summary/Summaries/entertainment/238.txt
# BBC News Summary/Summaries/entertainment/239.txt
# BBC News Summary/Summaries/entertainment/240.txt
# BBC News Summary/Summaries/entertainment/241.txt
# BBC News Summary/Summaries/entertainment/242.txt
# BBC News Summary/Summaries/entertainment/243.txt
# BBC News Summary/Summaries/entertainment/244.txt
# BBC News Summary/Summaries/entertainment/245.txt
# BBC News Summary/Summaries/entertainment/246.txt
# BBC News Summary/Summaries/entertainment/247.txt
# BBC News Summary/Summaries/entertainment/248.txt
# BBC News Summary/Summaries/entertainment/249.txt
# BBC News Summary/Summaries/entertainment/250.txt
# BBC News Summary/Summaries/entertainment/251.txt
# BBC News Summary/Summaries/entertainment/252.txt
# BBC News Summary/Summaries/entertainment/253.txt
# BBC News Summary/Summaries/entertainment/254.txt
# BBC News Summary/Summaries/entertainment/255.txt
# BBC News Summary/Summaries/entertainment/256.txt
# BBC News Summary/Summaries/entertainment/257.txt
# BBC News Summary/Summaries/entertainment/258.txt
# BBC News Summary/Summaries/entertainment/259.txt
# BBC News Summary/Summaries/entertainment/260.txt
# BBC News Summary/Summaries/entertainment/261.txt
# BBC News Summary/Summaries/entertainment/262.txt
# BBC News Summary/Summaries/entertainment/263.txt
# BBC News Summary/Summaries/entertainment/264.txt
# BBC News Summary/Summaries/entertainment/265.txt
# BBC News Summary/Summaries/entertainment/266.txt
# BBC News Summary/Summaries/entertainment/267.txt
# BBC News Summary/Summaries/entertainment/268.txt
# BBC News Summary/Summaries/entertainment/269.txt
# BBC News Summary/Summaries/entertainment/270.txt
# BBC News Summary/Summaries/entertainment/271.txt
# BBC News Summary/Summaries/entertainment/272.txt
# BBC News Summary/Summaries/entertainment/273.txt
# BBC News Summary/Summaries/entertainment/274.txt
# BBC News Summary/Summaries/entertainment/275.txt
# BBC News Summary/Summaries/entertainment/276.txt
# BBC News Summary/Summaries/entertainment/277.txt
# BBC News Summary/Summaries/entertainment/278.txt
# BBC News Summary/Summaries/entertainment/279.txt
# BBC News Summary/Summaries/entertainment/280.txt
# BBC News Summary/Summaries/entertainment/281.txt
# BBC News Summary/Summaries/entertainment/282.txt
# BBC News Summary/Summaries/entertainment/283.txt
# BBC News Summary/Summaries/entertainment/284.txt
# BBC News Summary/Summaries/entertainment/285.txt
# BBC News Summary/Summaries/entertainment/286.txt
# BBC News Summary/Summaries/entertainment/287.txt
# BBC News Summary/Summaries/entertainment/288.txt
# BBC News Summary/Summaries/entertainment/289.txt
# BBC News Summary/Summaries/entertainment/290.txt
# BBC News Summary/Summaries/entertainment/291.txt
# BBC News Summary/Summaries/entertainment/292.txt
# BBC News Summary/Summaries/entertainment/293.txt
# BBC News Summary/Summaries/entertainment/294.txt
# BBC News Summary/Summaries/entertainment/295.txt
# BBC News Summary/Summaries/entertainment/296.txt
# BBC News Summary/Summaries/entertainment/297.txt
# BBC News Summary/Summaries/entertainment/298.txt
# BBC News Summary/Summaries/entertainment/299.txt
# BBC News Summary/Summaries/entertainment/300.txt
# BBC News Summary/Summaries/entertainment/301.txt
# BBC News Summary/Summaries/entertainment/302.txt
# BBC News Summary/Summaries/entertainment/303.txt
# BBC News Summary/Summaries/entertainment/304.txt
# BBC News Summary/Summaries/entertainment/305.txt
# BBC News Summary/Summaries/entertainment/306.txt
# BBC News Summary/Summaries/entertainment/307.txt
# BBC News Summary/Summaries/entertainment/308.txt
# BBC News Summary/Summaries/entertainment/309.txt
# BBC News Summary/Summaries/entertainment/310.txt
# BBC News Summary/Summaries/entertainment/311.txt
# BBC News Summary/Summaries/entertainment/312.txt
# BBC News Summary/Summaries/entertainment/313.txt
# BBC News Summary/Summaries/entertainment/314.txt
# BBC News Summary/Summaries/entertainment/315.txt
# BBC News Summary/Summaries/entertainment/316.txt
# BBC News Summary/Summaries/entertainment/317.txt
# BBC News Summary/Summaries/entertainment/318.txt
# BBC News Summary/Summaries/entertainment/319.txt
# BBC News Summary/Summaries/entertainment/320.txt
# BBC News Summary/Summaries/entertainment/321.txt
# BBC News Summary/Summaries/entertainment/322.txt
# BBC News Summary/Summaries/entertainment/323.txt
# BBC News Summary/Summaries/entertainment/324.txt
# BBC News Summary/Summaries/entertainment/325.txt
# BBC News Summary/Summaries/entertainment/326.txt
# BBC News Summary/Summaries/entertainment/327.txt
# BBC News Summary/Summaries/entertainment/328.txt
# BBC News Summary/Summaries/entertainment/329.txt
# BBC News Summary/Summaries/entertainment/330.txt
# BBC News Summary/Summaries/entertainment/331.txt
# BBC News Summary/Summaries/entertainment/332.txt
# BBC News Summary/Summaries/entertainment/333.txt
# BBC News Summary/Summaries/entertainment/334.txt
# BBC News Summary/Summaries/entertainment/335.txt
# BBC News Summary/Summaries/entertainment/336.txt
# BBC News Summary/Summaries/entertainment/337.txt
# BBC News Summary/Summaries/entertainment/338.txt
# BBC News Summary/Summaries/entertainment/339.txt
# BBC News Summary/Summaries/entertainment/340.txt
# BBC News Summary/Summaries/entertainment/341.txt
# BBC News Summary/Summaries/entertainment/342.txt
# BBC News Summary/Summaries/entertainment/343.txt
# BBC News Summary/Summaries/entertainment/344.txt
# BBC News Summary/Summaries/entertainment/345.txt
# BBC News Summary/Summaries/entertainment/346.txt
# BBC News Summary/Summaries/entertainment/347.txt
# BBC News Summary/Summaries/entertainment/348.txt
# BBC News Summary/Summaries/entertainment/349.txt
# BBC News Summary/Summaries/entertainment/350.txt
# BBC News Summary/Summaries/entertainment/351.txt
# BBC News Summary/Summaries/entertainment/352.txt
# BBC News Summary/Summaries/entertainment/353.txt
# BBC News Summary/Summaries/entertainment/354.txt
# BBC News Summary/Summaries/entertainment/355.txt
# BBC News Summary/Summaries/entertainment/356.txt
# BBC News Summary/Summaries/entertainment/357.txt
# BBC News Summary/Summaries/entertainment/358.txt
# BBC News Summary/Summaries/entertainment/359.txt
# BBC News Summary/Summaries/entertainment/360.txt
# BBC News Summary/Summaries/entertainment/361.txt
# BBC News Summary/Summaries/entertainment/362.txt
# BBC News Summary/Summaries/entertainment/363.txt
# BBC News Summary/Summaries/entertainment/364.txt
# BBC News Summary/Summaries/entertainment/365.txt
# BBC News Summary/Summaries/entertainment/366.txt
# BBC News Summary/Summaries/entertainment/367.txt
# BBC News Summary/Summaries/entertainment/368.txt
# BBC News Summary/Summaries/entertainment/369.txt
# BBC News Summary/Summaries/entertainment/370.txt
# BBC News Summary/Summaries/entertainment/371.txt
# BBC News Summary/Summaries/entertainment/372.txt
# BBC News Summary/Summaries/entertainment/373.txt
# BBC News Summary/Summaries/entertainment/374.txt
# BBC News Summary/Summaries/entertainment/375.txt
# BBC News Summary/Summaries/entertainment/376.txt
# BBC News Summary/Summaries/entertainment/377.txt
# BBC News Summary/Summaries/entertainment/378.txt
# BBC News Summary/Summaries/entertainment/379.txt
# BBC News Summary/Summaries/entertainment/380.txt
# BBC News Summary/Summaries/entertainment/381.txt
# BBC News Summary/Summaries/entertainment/382.txt
# BBC News Summary/Summaries/entertainment/383.txt
# BBC News Summary/Summaries/entertainment/384.txt
# BBC News Summary/Summaries/entertainment/385.txt
# BBC News Summary/Summaries/entertainment/386.txt
# BBC News Summary/Summaries/politics/001.txt
# BBC News Summary/Summaries/politics/002.txt
# BBC News Summary/Summaries/politics/003.txt
# BBC News Summary/Summaries/politics/004.txt
# BBC News Summary/Summaries/politics/005.txt
# BBC News Summary/Summaries/politics/006.txt
# BBC News Summary/Summaries/politics/007.txt
# BBC News Summary/Summaries/politics/008.txt
# BBC News Summary/Summaries/politics/009.txt
# BBC News Summary/Summaries/politics/010.txt
# BBC News Summary/Summaries/politics/011.txt
# BBC News Summary/Summaries/politics/012.txt
# BBC News Summary/Summaries/politics/013.txt
# BBC News Summary/Summaries/politics/014.txt
# BBC News Summary/Summaries/politics/015.txt
# BBC News Summary/Summaries/politics/016.txt
# BBC News Summary/Summaries/politics/017.txt
# BBC News Summary/Summaries/politics/018.txt
# BBC News Summary/Summaries/politics/019.txt
# BBC News Summary/Summaries/politics/020.txt
# BBC News Summary/Summaries/politics/021.txt
# BBC News Summary/Summaries/politics/022.txt
# BBC News Summary/Summaries/politics/023.txt
# BBC News Summary/Summaries/politics/024.txt
# BBC News Summary/Summaries/politics/025.txt
# BBC News Summary/Summaries/politics/026.txt
# BBC News Summary/Summaries/politics/027.txt
# BBC News Summary/Summaries/politics/028.txt
# BBC News Summary/Summaries/politics/029.txt
# BBC News Summary/Summaries/politics/030.txt
# BBC News Summary/Summaries/politics/031.txt
# BBC News Summary/Summaries/politics/032.txt
# BBC News Summary/Summaries/politics/033.txt
# BBC News Summary/Summaries/politics/034.txt
# BBC News Summary/Summaries/politics/035.txt
# BBC News Summary/Summaries/politics/036.txt
# BBC News Summary/Summaries/politics/037.txt
# BBC News Summary/Summaries/politics/038.txt
# BBC News Summary/Summaries/politics/039.txt
# BBC News Summary/Summaries/politics/040.txt
# BBC News Summary/Summaries/politics/041.txt
# BBC News Summary/Summaries/politics/042.txt
# BBC News Summary/Summaries/politics/043.txt
# BBC News Summary/Summaries/politics/044.txt
# BBC News Summary/Summaries/politics/045.txt
# BBC News Summary/Summaries/politics/046.txt
# BBC News Summary/Summaries/politics/047.txt
# BBC News Summary/Summaries/politics/048.txt
# BBC News Summary/Summaries/politics/049.txt
# BBC News Summary/Summaries/politics/050.txt
# BBC News Summary/Summaries/politics/051.txt
# BBC News Summary/Summaries/politics/052.txt
# BBC News Summary/Summaries/politics/053.txt
# BBC News Summary/Summaries/politics/054.txt
# BBC News Summary/Summaries/politics/055.txt
# BBC News Summary/Summaries/politics/056.txt
# BBC News Summary/Summaries/politics/057.txt
# BBC News Summary/Summaries/politics/058.txt
# BBC News Summary/Summaries/politics/059.txt
# BBC News Summary/Summaries/politics/060.txt
# BBC News Summary/Summaries/politics/061.txt
# BBC News Summary/Summaries/politics/062.txt
# BBC News Summary/Summaries/politics/063.txt
# BBC News Summary/Summaries/politics/064.txt
# BBC News Summary/Summaries/politics/065.txt
# BBC News Summary/Summaries/politics/066.txt
# BBC News Summary/Summaries/politics/067.txt
# BBC News Summary/Summaries/politics/068.txt
# BBC News Summary/Summaries/politics/069.txt
# BBC News Summary/Summaries/politics/070.txt
# BBC News Summary/Summaries/politics/071.txt
# BBC News Summary/Summaries/politics/072.txt
# BBC News Summary/Summaries/politics/073.txt
# BBC News Summary/Summaries/politics/074.txt
# BBC News Summary/Summaries/politics/075.txt
# BBC News Summary/Summaries/politics/076.txt
# BBC News Summary/Summaries/politics/077.txt
# BBC News Summary/Summaries/politics/078.txt
# BBC News Summary/Summaries/politics/079.txt
# BBC News Summary/Summaries/politics/080.txt
# BBC News Summary/Summaries/politics/081.txt
# BBC News Summary/Summaries/politics/082.txt
# BBC News Summary/Summaries/politics/083.txt
# BBC News Summary/Summaries/politics/084.txt
# BBC News Summary/Summaries/politics/085.txt
# BBC News Summary/Summaries/politics/086.txt
# BBC News Summary/Summaries/politics/087.txt
# BBC News Summary/Summaries/politics/088.txt
# BBC News Summary/Summaries/politics/089.txt
# BBC News Summary/Summaries/politics/090.txt
# BBC News Summary/Summaries/politics/091.txt
# BBC News Summary/Summaries/politics/092.txt
# BBC News Summary/Summaries/politics/093.txt
# BBC News Summary/Summaries/politics/094.txt
# BBC News Summary/Summaries/politics/095.txt
# BBC News Summary/Summaries/politics/096.txt
# BBC News Summary/Summaries/politics/097.txt
# BBC News Summary/Summaries/politics/098.txt
# BBC News Summary/Summaries/politics/099.txt
# BBC News Summary/Summaries/politics/100.txt
# BBC News Summary/Summaries/politics/101.txt
# BBC News Summary/Summaries/politics/102.txt
# BBC News Summary/Summaries/politics/103.txt
# BBC News Summary/Summaries/politics/104.txt

# %% [markdown]
# ## EDA

# %%
#dump ZIP file i.e bbc summary data to jupyter notebook and read it 
articles_path = './BBC News Summary/News Articles'
summaries_path ='./BBC News Summary/Summaries'
categories_list = ['politics', 'sport', 'tech', 'entertainment', 'business']

# %%
#data into summary and text format
def read_files_from_folders(articles_path,summaries_path,categories_list, encoding = "ISO-8859-1"):
    articles = []
    summaries = []
    categories = []
    for category in categories_list:
        article_paths =  glob.glob(os.path.join(articles_path , category , '*.txt'), recursive=True)
        summary_paths =  glob.glob(os.path.join(summaries_path , category , '*.txt'), recursive=True)

        print(f'found {len(article_paths)} file in articles/{category} folder, {len(summary_paths)} file in summaries/{category} folder')

        if len(article_paths) != len(summary_paths):
            print('number of files is not equal') 
            return    
        for idx_file in range(len(article_paths)):
            categories.append(category)
            with open(article_paths[idx_file], mode = 'r', encoding = encoding) as file:
                articles.append(file.read())


            with open(summary_paths[idx_file], mode = 'r', encoding = encoding) as file:
                 summaries.append(file.read())
    
    print(f'total {len(articles)} file in articles folders, {len(summaries)} file in summaries folders')
    return articles, summaries, categories

# %%
#files in articles and summary 
articles, summaries, categories = read_files_from_folders(articles_path, summaries_path, categories_list)
# Out:
# found 417 file in articles/politics folder, 417 file in summaries/politics folder
# found 511 file in articles/sport folder, 511 file in summaries/sport folder
# found 401 file in articles/tech folder, 401 file in summaries/tech folder
# found 386 file in articles/entertainment folder, 386 file in summaries/entertainment folder
# found 510 file in articles/business folder, 510 file in summaries/business folder
# total 2225 file in articles folders, 2225 file in summaries folders

# %%
#glacing at articles
test_file = './BBC News Summary/News Articles/business/008.txt'
with open(test_file, mode = 'r', encoding = "ISO-8859-1") as file:
    print(file.read())
# Out:
# India calls for fair trade rules
#
# India, which attends the G7 meeting of seven leading industrialised nations on Friday, is unlikely to be cowed by its newcomer status.
#
# In London on Thursday ahead of the meeting, India's finance minister, lashed out at the restrictive trade policies of the G7 nations. He objected to subsidies on agriculture that make it hard for developing nations like India to compete. He also called for reform of the United Nations, the World Bank and the IMF.
#
# Palaniappan Chidambaram, India's finance minister, argued that these organisations need to take into account the changing world order, given India and China's integration into the global economy. He said the issue is not globalisation but "the terms of engagement in globalisation." Mr Chidambaram is attending the G7 meeting as part of the G20 group of nations, which account for two thirds of the world's population. At a conference on developing enterprise hosted by UK finance minister Gordon Brown on Friday, he said that he was in favour of floating exchange rates because they help countries cope with economic shocks. "A flexible exchange rate is one more channel for absorbing both positive and negative shocks," he told the conference. India, along with China, Brazil, South Africa and Russia, has been invited to take part in the G7 meeting taking place in London on Friday and Saturday. China is expected to face renewed pressure to abandon its fixed exchange rate, which G7 nations, in particular the US, have blamed for a surge in cheap Chinese exports. "Some countries have tried to use fixed exchange rates. I do not wish to make any judgements," Mr Chidambaram said. Separately, the IMF warned on Thursday that India's budget deficit was too large and would hamper the country's economic growth, which it forecast to be around 6.5% in the year to March 2005. In the year to March 2004, the Indian economy grew by 8.5%.

# %%
#all data into into a dataframe 
df = pd.DataFrame({'articles':articles,'summaries': summaries, 'categories' : categories},)
df
# Out:
#                                                articles  \
# 0     Howard taunts Blair over splits\n\nTony Blair'...
# 1     Chancellor rallies Labour voters\n\nGordon Bro...
# 2     Boothroyd calls for Lords speaker\n\nBetty Boo...
# 3     Iraqis win death test case probe\n\nThe family...
# 4     'More to do' on adult literacy\n\nThe governme...
# ...                                                 ...
# 2220  Unilever shake up as profit slips\n\nAnglo-Dut...
# 2221  Yukos seeks court action on sale\n\nYukos will...
# 2222  Small firms 'hit by rising costs'\n\nRising fu...
# 2223  GM pays $2bn to evade Fiat buyout\n\nGeneral M...
# 2224  Ask Jeeves tips online ad revival\n\nAsk Jeeve...
#
#                                               summaries categories
# 0     It claims Mr Blair said in November 2003 he wo...   politics
# 1     He said Tory plans to cut Â£35bn tax would "cu...   politics
# 2     The lord chancellor currently has the role of ...   politics
# 3     They said as Mr Mousa was in custody when he d...   politics
# 4     An estimated 5.2 million adults have worse lit...   politics
# ...                                                 ...        ...
# 2220  The company also said it planned to spend 500m...   business
# 2221  Yukos will return to a US court on Wednesday t...   business
# 2222  A CBI quarterly survey found output had risen ...   business
# 2223  Instead, GM swapped a 6% stake in itself for 2...   business
# 2224  Ask Jeeves has become the third leading online...   business
#
# [2225 rows x 3 columns]

# %%
#EDA on the dataframe 
df['articles_length'] = df['articles'].apply(lambda x : len(x.split()))
df['summaries_length'] = df['summaries'].apply(lambda x : len(x.split()))

# %%
df.head()
# Out:
#                                             articles  \
# 0  Howard taunts Blair over splits\n\nTony Blair'...
# 1  Chancellor rallies Labour voters\n\nGordon Bro...
# 2  Boothroyd calls for Lords speaker\n\nBetty Boo...
# 3  Iraqis win death test case probe\n\nThe family...
# 4  'More to do' on adult literacy\n\nThe governme...
#
#                                            summaries categories  \
# 0  It claims Mr Blair said in November 2003 he wo...   politics
# 1  He said Tory plans to cut Â£35bn tax would "cu...   politics
# 2  The lord chancellor currently has the role of ...   politics
# 3  They said as Mr Mousa was in custody when he d...   politics
# 4  An estimated 5.2 million adults have worse lit...   politics
#
#    articles_length  summaries_length
# 0              494               220
# 1              399               170
# 2              277               116
# 3              481               214
# 4              495               209

# %%
category_length = df.groupby('categories',0).agg( {'articles_length':'mean', 'summaries_length':'mean'} )
category_length
# Out:
#                articles_length  summaries_length
# categories
# business            328.880392        139.929412
# entertainment       330.621762        144.049223
# politics            453.973621        195.709832
# sport               329.262231        143.187867
# tech                502.695761        213.837905

# %% [markdown]
# #### FINDINGS: stats for mean for summary and text length(mean)  categories wise

# %%
category_length = df.groupby('categories',0).agg( {'articles_length':'mean', 'summaries_length':'mean'} )
df_m = pd.melt(category_length,ignore_index=False)
plt.figure(figsize=(8,6))
sns.barplot(x=df_m.index, y="value",hue='variable', data= df_m)
plt.show()

# %%
pd.melt(category_length,ignore_index=False).groupby('variable').mean()
# Out:
#                        value
# variable
# articles_length   389.086753
# summaries_length  167.342848

# %% [markdown]
# #### FINDINGS: stats for mean for summary and text length(mean)

# %%
import numpy as np
import pandas as pd
#split df into train,val,test
def train_validate_test_split(df, train_percent=.8, validate_percent=.1, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

# %%
train, validate, test = train_validate_test_split(df)

# %%
train
# Out:
#                                                articles  \
# 1939  Pension hitch for long-living men\n\nMale life...
# 91    Brown's poll campaign move denied\n\nThe gover...
# 32    Vouchers 'to cut winter deaths'\n\nPensioners ...
# 725   McIlroy continues winning streak\n\nJames McIl...
# 1841  Amex shares up on spin-off news\n\nShares in A...
# ...                                                 ...
# 1838  BMW to recall faulty diesel cars\n\nBMW is to ...
# 129   Parties' plans for council tax\n\nAnger at cou...
# 1317  Slow start to speedy net services\n\nFaster br...
# 1888  Markets signal Brazilian recovery\n\nThe Brazi...
# 676   Radcliffe eyes hard line on drugs\n\nPaula Rad...
#
#                                               summaries categories  \
# 1939  "Even people in social class V [unskilled manu...   business
# 91    Labour has always maintained Mr Brown would ha...   politics
# 32    The plan would boost energy conservation, says...   politics
# 725   James McIlroy stormed to his second internatio...      sport
# 1841  The US credit card to travel services giant sa...   business
# ...                                                 ...        ...
# 1838  BMW is to recall all cars equipped with a faul...   business
# 129   The Tories have promised a reduction on bills ...   politics
# 1317  For BT Retail, she said, the super-fast servic...       tech
# 1888  Investors have praised his handling of the eco...   business
# 676   Paula Radcliffe has called for all athletes fo...      sport
#
#       articles_length  summaries_length
# 1939              212               100
# 91                276               118
# 32                181               103
# 725               203                90
# 1841              168                82
# ...               ...               ...
# 1838              265               112
# 129               473               215
# 1317              273               130
# 1888              382               164
# 676               195                81
#
# [1780 rows x 5 columns]

# %%
#dump data in usable format 
test.to_csv('test_bbc_news_data.csv')
validate.to_csv('val_bcc_news_data.csv')
train.to_csv('train_bcc_news_data.csv')

# %% [markdown]
# ## Tranformers Training for Text Summarisation

# %%
#installation 
# !pip install "sagemaker>=2.48.0" "transformers==4.6.1" "datasets[s3]==1.6.2" --upgrade
# install pytorch lib if not already installed
# Out:
# Requirement already satisfied: sagemaker>=2.48.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (2.69.0)
# Collecting sagemaker>=2.48.0
#   Using cached sagemaker-2.96.0.tar.gz (534 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers==4.6.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (4.6.1)
# Requirement already satisfied: datasets[s3]==1.6.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (1.6.2)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (0.10.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (2.25.1)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (0.0.53)
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (2021.4.4)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (4.49.0)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (4.5.0)
# Requirement already satisfied: huggingface-hub==0.0.8 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (0.0.8)
# Requirement already satisfied: dataclasses in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (0.8)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==4.6.1) (21.3)
# Requirement already satisfied: dill in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (0.3.4)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (2021.4.0)
# Requirement already satisfied: xxhash in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (3.0.0)
# Requirement already satisfied: pyarrow>=1.0.0<4.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (6.0.1)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (1.1.5)
# Requirement already satisfied: multiprocess in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (0.70.12.2)
# Requirement already satisfied: boto3==1.16.43 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (1.16.43)
# Requirement already satisfied: botocore==1.19.52 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (1.19.52)
# Requirement already satisfied: s3fs in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from datasets[s3]==1.6.2) (2021.4.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3==1.16.43->datasets[s3]==1.6.2) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3==1.16.43->datasets[s3]==1.6.2) (0.3.7)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore==1.19.52->datasets[s3]==1.6.2) (1.26.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore==1.19.52->datasets[s3]==1.6.2) (2.8.1)
# Requirement already satisfied: attrs==20.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker>=2.48.0) (20.3.0)
#   Using cached sagemaker-2.95.0.tar.gz (530 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.94.0.tar.gz (527 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.93.1.tar.gz (527 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.93.0.tar.gz (537 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.92.2.tar.gz (537 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.92.1.tar.gz (536 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.92.0.tar.gz (536 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.91.1.tar.gz (534 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.91.0.tar.gz (534 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.90.0.tar.gz (534 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.89.0.tar.gz (529 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.88.3.tar.gz (529 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.88.2.tar.gz (529 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.88.1.tar.gz (527 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.88.0.tar.gz (527 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.87.0.tar.gz (522 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.86.2.tar.gz (521 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.86.1.tar.gz (521 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.86.0.tar.gz (521 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.85.0.tar.gz (521 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.84.0.tar.gz (520 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.83.0.tar.gz (520 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.82.2.tar.gz (520 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.82.1.tar.gz (520 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.82.0.tar.gz (520 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.81.1.tar.gz (519 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.81.0.tar.gz (519 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.80.0-py2.py3-none-any.whl
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker>=2.48.0) (3.17.2)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker>=2.48.0) (0.1.5)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker>=2.48.0) (1.0.1)
#   Using cached sagemaker-2.79.0.tar.gz (516 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.78.0.tar.gz (513 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.77.1.tar.gz (513 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.77.0.tar.gz (513 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.76.0.tar.gz (512 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.75.1.tar.gz (511 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.75.0.tar.gz (511 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.74.0.tar.gz (481 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.73.0.tar.gz (481 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.72.3.tar.gz (475 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.72.2.tar.gz (473 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.72.1.tar.gz (473 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.72.0.tar.gz (477 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.71.0.tar.gz (477 kB)
#   Preparing metadata (setup.py) ... done
#   Using cached sagemaker-2.70.0.tar.gz (466 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker>=2.48.0) (0.2.0)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker>=2.48.0) (0.2.8)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata->transformers==4.6.1) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata->transformers==4.6.1) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from packaging->transformers==4.6.1) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker>=2.48.0) (1.16.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==4.6.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==4.6.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==4.6.1) (2021.5.30)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pandas->datasets[s3]==1.6.2) (2021.1)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pathos->sagemaker>=2.48.0) (1.6.6.4)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pathos->sagemaker>=2.48.0) (0.3.0)
# Requirement already satisfied: aiobotocore>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from s3fs->datasets[s3]==1.6.2) (1.2.2)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sacremoses->transformers==4.6.1) (1.0.1)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sacremoses->transformers==4.6.1) (8.0.1)
# Requirement already satisfied: aioitertools>=0.5.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (0.7.1)
# Requirement already satisfied: wrapt>=1.10.10 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (1.12.1)
# Requirement already satisfied: aiohttp>=3.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (3.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (5.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (4.0.1)
# Requirement already satisfied: asynctest==0.13.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (2.0.9)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (1.6.3)
# Requirement already satisfied: idna-ssl>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (1.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=1.0.1->s3fs->datasets[s3]==1.6.2) (1.2.0)

# %%
#imports for huggingface
import transformers
import sagemaker
from sagemaker.huggingface import HuggingFace
from datasets import load_dataset
from transformers import AutoTokenizer

# %%
#setting up session,role and s3 bucket
sess = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sess.default_bucket()

print(f"IAM role arn used for running training: {role}")
print(f"S3 bucket used for storing artifacts: {sess.default_bucket()}")
# Out:
# IAM role arn used for running training: arn:aws:iam::748276930737:role/SagemakerNotebookGenericAccess
# S3 bucket used for storing artifacts: sagemaker-ap-south-1-748276930737

# %%
#passing github repo
git_config = {'repo': 'https://github.com/huggingface/transformers.git','branch': 'v4.6.1'}

# %%
# enables spot training for cost saving 
use_spot_instances=True
# max time including spot start + training time
max_wait=7200
# expected training time
max_run=4000

distribution = {'smdistributed':{'dataparallel':{ 'enabled': False }}}

# %% [markdown]
# ##### Training model using Hugging Face AWS Deep Learning Containers
# ##### These containers include Hugging Face Transformers, Tokenizers and the Datasets library
# ##### Which allows us to use these resources for training and inference jobs

# %% [markdown]
# ### Training First Transformer
# ### Pegasus

# %%
#local path in the hyperparameters section of the training job
hyperparameters={
     'train_file':'/opt/ml/input/data/train/train_bcc_news_data.csv',
     'validation_file':'/opt/ml/input/data/validation/val_bcc_news_data.csv',
     'summary_column':'summary',
     'text_column':'text',
     'per_device_train_batch_size': 2,
     'per_device_eval_batch_size': 2,
     'model_name_or_path':'google/pegasus-cnn_dailymail', # Pre-trained Pegasus model
     'do_train':True,
     'do_eval':True,
     'output_dir':'/opt/ml/model',
     'text_column': 'articles',
     'summary_column': 'summaries',
     'num_train_epochs': 6,
     'learning_rate': 5e-5,
     'seed': 7,
     'load_best_model_at_end':True,
     'max_source_length': 512,
     'report_to': 'wandb',    # ✍️
#      'run_name': 'hpt' 
     #'load_best_model_at_end':True
    # This is the maximum sequence length supported by Pegasus
 }

# create the Estimator
huggingface_estimator = HuggingFace(
    entry_point='run_summarization.py',
    source_dir='./examples/pytorch/summarization',
    git_config=git_config,
    instance_type='ml.g4dn.xlarge',
    instance_count=1,
    use_spot_instances=True,
    max_wait=3600,# max_wait should be equal to or greater than max_run in seconds
    max_run=1000,
    transformers_version='4.6',
    pytorch_version='1.7',
    py_version='py36',
    role=role,
    hyperparameters=hyperparameters,
    distribution=distribution,
)

# %%
#When executing the fit() method on the training task,
#We specify where the data are located in Amazon S3.
huggingface_estimator.fit({'train':f's3://{bucket}/data_bbc/train_bcc_news_data.csv',
                           'validation':f's3://{bucket}/data_bbc/val_bcc_news_data.csv'})

# %% [markdown]
# ### Evaluate the Pegasus Model

# %%
# we have two options
# First is deploying model using sagemaker endpoint 
# Dowloading the trained model locally 
# 1)We choose first option as we can access model from s3 directly 
# 2)As we can choose a gpu instance for the endpoint we can decrease inference time significantly

# %%
# specifying pegasus model training job  
training_job = 'huggingface-pytorch-training-2022-06-23-09-38-10-404'
#training_job = client.list_training_jobs()['TrainingJobSummaries'][0]['TrainingJobName']
model_data = sess.describe_training_job(training_job)['ModelArtifacts']['S3ModelArtifacts']
model_data
# Out:
# 's3://sagemaker-ap-south-1-748276930737/huggingface-pytorch-training-2022-06-23-09-38-10-404/output/model.tar.gz'

# %% [markdown]
# ### Deploy the Peagsus model
#
# #### the model is deployed using estimator.deploy()

# %%
from datasets import load_metric
metric = load_metric("rouge")

# %%
from sagemaker.huggingface import HuggingFaceModel

model_for_deployment = HuggingFaceModel(entry_point='inference.py',
                                        source_dir='./text-summarisation-project/inference_code',
                                        model_data=model_data,
                                        role=role,
                                        pytorch_version='1.7.1',
                                        py_version='py36',
                                        transformers_version='4.6.1',
                                        )

# %%
predictor_pegasus = model_for_deployment.deploy(initial_instance_count=1,
                                        instance_type='ml.g4dn.xlarge',
                                        serializer=sagemaker.serializers.JSONSerializer(),
                                        deserializer=sagemaker.deserializers.JSONDeserializer()
                                        )
# Out:
# ------!

# %%
# reading val data
df_test = pd.read_csv('test_bbc_news_data.csv')
ref_summaries = list(df_test['summaries'])
texts = list(df_test['articles'])

# %%
len(ref_summaries[0])
# Out:
# 754

# %%
ref_summaries[0]
# Out:
# 'LG Card had been threatened with collapse because of its huge debts but the firm\'s creditors and its former parent have stepped in to rescue it.South Korea\'s largest credit card firm has averted liquidation following a one trillion won ($960m; Â£499m) bail-out.The firm\'s creditors - which own 99% of LG Card - have been trying to agree a deal to secure its future for several weeks.LG Card returned to profit in September but needed further capital to avoid being thrown off the market.LG Card has seven million customers and its collapse would have sent shockwaves through the country\'s economy."LG Card will not need any more financial aid after this," Laah Chong-gyu, executive director of Korea Development Bank - one of the firm\'s creditors - said.'

# %%
texts[0]
# Out:
# 'S Korean credit card firm rescued\n\nSouth Korea\'s largest credit card firm has averted liquidation following a one trillion won ($960m; Â£499m) bail-out.\n\nLG Card had been threatened with collapse because of its huge debts but the firm\'s creditors and its former parent have stepped in to rescue it. A consortium of creditors and LG Group, a family owned conglomerate, have each put up $480m to stabilise the firm. LG Card has seven million customers and its collapse would have sent shockwaves through the country\'s economy.\n\nThe firm\'s creditors - which own 99% of LG Card - have been trying to agree a deal to secure its future for several weeks. They took control of the company in January when it avoided bankruptcy only through a $4.5bn bail-out.\n\nThey had threatened to delist the company, a move which would have triggered massive debt redemptions and forced the company into bankruptcy, unless agreement was reached on its future funding. "LG Card will not need any more financial aid after this," Laah Chong-gyu, executive director of Korea Development Bank - one of the firm\'s creditors - said.\n\nThe agreement will see some 12 trillion won of debt converted into equity. "The purpose of the capital injection is to avoid delisting and the goal will be met," David Kim, an analyst at Sejong Securities, told Reuters. South Korea\'s consumer credit market has been slowly recovering from a crisis in 2002 when a credit bubble burst and millions of consumers fell behind on their debt repayments. LG Card returned to profit in September but needed further capital to avoid being thrown off the market. South Korea\'s stock exchange can delist any firm if its debt exceeds its assets two years running.\n'

# %% [markdown]
# #### No longer than 30 seconds read is max of 90 words
# #### we will use min legth of 20 and max of 90 for making summaries as per bussiness requirement /

# %%
candidate_summaries_pegasus = []

for i, text in enumerate(texts):
    if i % 100 == 0:
        print(i)
    data = {"inputs":text, "parameters_list":[{"min_length": 20, "max_length": 90}]}
    candidate_pegasus = predictor_pegasus.predict(data)
    candidate_summaries_pegasus.append(candidate_pegasus[0][0])
# Out:
# 0
# 100
# 200

# %%
def calc_rouge_scores(candidates, references):
    result = metric.compute(predictions=candidates, references=references, use_stemmer=True)
    print(result)
    result = {key: round(value.mid.fmeasure * 100, 1) for key, value in result.items()}
    return result

# %%
calc_rouge_scores(candidate_summaries_pegasus, ref_summaries)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.9274717824339371, recall=0.4520188397206453, fmeasure=0.5859853828137624), mid=Score(precision=0.941329656135676, recall=0.4759011622409097, fmeasure=0.6082421666172781), high=Score(precision=0.9543440939763077, recall=0.49887533525010375, fmeasure=0.6278673680810242)), 'rouge2': AggregateScore(low=Score(precision=0.8716887673022384, recall=0.42386579290078014, fmeasure=0.5510705491611586), mid=Score(precision=0.8925678099065982, recall=0.4461116062690913, fmeasure=0.5719399299334966), high=Score(precision=0.9111752268248845, recall=0.4730880949771845, fmeasure=0.5953049122451453)), 'rougeL': AggregateScore(low=Score(precision=0.7397224353591033, recall=0.3615918312911822, fmeasure=0.46872105291297617), mid=Score(precision=0.7611237682591868, recall=0.38389110404648674, fmeasure=0.49050495942454564), high=Score(precision=0.7829786793287019, recall=0.4055873897871912, fmeasure=0.5104816821385586)), 'rougeLsum': AggregateScore(low=Score(precision=0.7405961303855374, recall=0.3615519335629073, fmeasure=0.46863177808759643), mid=Score(precision=0.7610947075832257, recall=0.38371481465876417, fmeasure=0.49051545433405647), high=Score(precision=0.7816662839639767, recall=0.40650894517090924, fmeasure=0.5128372956015331))}
# {'rouge1': 60.8, 'rouge2': 57.2, 'rougeL': 49.1, 'rougeLsum': 49.1}

# %%
##findings from the first experiment i.e pegasus 

# the model is already trained on

# %%
candidate_summaries_pegasus[48]
# Out:
# 'There were fears that the potential increase of shares in circulation from Tuesday would ease demand for stock.Shares in Google have fallen 6.7% after employees and early investors in the web search took advantage of the first chance to sell their holdings.In its first earnings report since floating on the stock market, Google said it made a net profit of $52m in the three months ending 30 September.Google shares have risen since but fell $12.33 on Tuesday'

# %%
ref_summaries[48]
# Out:
# "Google shares have risen since but fell $12.33 on Tuesday to close at $172.55.There were fears that the potential increase of shares in circulation from Tuesday would ease demand for stock.In one of the most closely-watched initial public offerings in stock market history, the US-based company sold 19.6 million shares at $85 each.Selling the shares could turn many of Google's workers into millionaires.However, analysts say they expected most shareholders would be holding back from selling all their shares immediately, as Google's good performance and future growth potential means demand will hold."

# %% [markdown]
# ### Training Second model
# #### T5

# %%
#local path in the hyperparameters section of the training job
hyperparameters={
     'train_file':'/opt/ml/input/data/train/train_bcc_news_data.csv',
     'validation_file':'/opt/ml/input/data/validation/val_bcc_news_data.csv',
     'summary_column':'summary',
     'text_column':'text',
     'per_device_train_batch_size': 2,
     'per_device_eval_batch_size': 2,
     'model_name_or_path':'mrm8488/t5-base-finetuned-summarize-news', # Pre-trained Pegasus model
     'do_train':True,
     'do_eval':True,
     'output_dir':'/opt/ml/model',
     'text_column': 'articles',
     'summary_column': 'summaries',
     'num_train_epochs': 6,
     'learning_rate': 5e-5,
     'seed': 7,
     'load_best_model_at_end':True,
     'max_source_length': 512,
     'report_to': 'wandb',    # ✍️
#      'run_name': 'hpt' 
     #'load_best_model_at_end':True
    # This is the maximum sequence length supported by Pegasus
 }

# create the Estimator
huggingface_estimator = HuggingFace(
    entry_point='run_summarization.py',
    source_dir='./examples/pytorch/summarization',
    git_config=git_config,
    instance_type='ml.g4dn.xlarge',
    instance_count=1,
    use_spot_instances=True,
    max_wait=3600,# max_wait should be equal to or greater than max_run in seconds
    max_run=1000,
    transformers_version='4.6',
    pytorch_version='1.7',
    py_version='py36',
    role=role,
    hyperparameters=hyperparameters,
    distribution=distribution,
)

# %%
#When executing the fit() method on the training task,
#We specify where the data are located in Amazon S3.
huggingface_estimator.fit({'train':f's3://{bucket}/data_bbc/train_bcc_news_data.csv',
                           'validation':f's3://{bucket}/data_bbc/val_bcc_news_data.csv'})

# %% [markdown]
# ### Evaluating T5 model

# %%
# specifying pegasus model training job  
training_job = 'huggingface-pytorch-training-2022-06-23-08-37-44-466'
#training_job = client.list_training_jobs()['TrainingJobSummaries'][0]['TrainingJobName']
model_data = sess.describe_training_job(training_job)['ModelArtifacts']['S3ModelArtifacts']
model_data
# Out:
# 's3://sagemaker-ap-south-1-748276930737/huggingface-pytorch-training-2022-06-23-08-37-44-466/output/model.tar.gz'

# %% [markdown]
# ### Deploy the T5 model
#
# #### the model is deployed using estimator.deploy()

# %%
from datasets import load_metric
metric = load_metric("rouge")

# %%
from sagemaker.huggingface import HuggingFaceModel

model_for_deployment = HuggingFaceModel(entry_point='inference.py',
                                        source_dir='./text-summarisation-project/inference_code',
                                        model_data=model_data,
                                        role=role,
                                        pytorch_version='1.7.1',
                                        py_version='py36',
                                        transformers_version='4.6.1',
                                        )

predictor_t5 = model_for_deployment.deploy(initial_instance_count=1,
                                        instance_type='ml.g4dn.xlarge',
                                        serializer=sagemaker.serializers.JSONSerializer(),
                                        deserializer=sagemaker.deserializers.JSONDeserializer()
                                        )
# Out:
# ------!

# %%
candidate_summaries_t5 = []
for i, text in enumerate(texts):
    if i % 100 == 0:
        print(i)
    data = {"inputs":text, "parameters_list":[{"min_length": 20, "max_length": 90}]}
    candidate_t5 = predictor_t5.predict(data)
    candidate_summaries_t5.append(candidate_t5[0][0])
# Out:
# 0
# 100
# 200

# %%
def calc_rouge_scores(candidates, references):
    result = metric.compute(predictions=candidates, references=references, use_stemmer=True)
    print(result)
    result = {key: round(value.mid.fmeasure * 100, 1) for key, value in result.items()}
    return result

# %%
calc_rouge_scores(candidate_summaries_t5, ref_summaries)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.8998294229422342, recall=0.390032872938484, fmeasure=0.5261800280439577), mid=Score(precision=0.9155649452408563, recall=0.4110946733105683, fmeasure=0.5466619029692339), high=Score(precision=0.9288744381627484, recall=0.4323563441660884, fmeasure=0.5666928836593932)), 'rouge2': AggregateScore(low=Score(precision=0.8127765952005438, recall=0.35440812363148494, fmeasure=0.47761064050035623), mid=Score(precision=0.8368291814169075, recall=0.374642507338377, fmeasure=0.49884032045298454), high=Score(precision=0.8573943598352642, recall=0.39623713572796304, fmeasure=0.5211777837133877)), 'rougeL': AggregateScore(low=Score(precision=0.709257332666547, recall=0.3056804636401136, fmeasure=0.41374444896479096), mid=Score(precision=0.7313149777471055, recall=0.326581661965902, fmeasure=0.43469811939505476), high=Score(precision=0.7541651779310631, recall=0.34464680700760764, fmeasure=0.4540782894227583)), 'rougeLsum': AggregateScore(low=Score(precision=0.7087615578755443, recall=0.3065865811951284, fmeasure=0.41459636106423403), mid=Score(precision=0.7312493877207273, recall=0.3266553979292976, fmeasure=0.4348862280620006), high=Score(precision=0.7527788806473478, recall=0.34560461339036114, fmeasure=0.4536838896496699))}
# {'rouge1': 54.7, 'rouge2': 49.9, 'rougeL': 43.5, 'rougeLsum': 43.5}

# %%
candidate_summaries_t5[48]
# Out:
# "There were fears that the potential increase of shares in circulation from Tuesday would ease demand for stock.Shares in Google have fallen 6.7% after employees and early investors in the web search took advantage of the first chance to sell their holdings.However, analysts say they expected most shareholders would be holding back from selling all their shares immediately, as Google's good performance and future growth potential means demand will hold.Google shares have risen since"

# %%
calc_rouge_scores(candidate_summaries_t5, ref_summaries)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.8998294229422342, recall=0.390032872938484, fmeasure=0.5261800280439577), mid=Score(precision=0.9155649452408563, recall=0.4110946733105683, fmeasure=0.5466619029692339), high=Score(precision=0.9288744381627484, recall=0.4323563441660884, fmeasure=0.5666928836593932)), 'rouge2': AggregateScore(low=Score(precision=0.8127765952005438, recall=0.35440812363148494, fmeasure=0.47761064050035623), mid=Score(precision=0.8368291814169075, recall=0.374642507338377, fmeasure=0.49884032045298454), high=Score(precision=0.8573943598352642, recall=0.39623713572796304, fmeasure=0.5211777837133877)), 'rougeL': AggregateScore(low=Score(precision=0.709257332666547, recall=0.3056804636401136, fmeasure=0.41374444896479096), mid=Score(precision=0.7313149777471055, recall=0.326581661965902, fmeasure=0.43469811939505476), high=Score(precision=0.7541651779310631, recall=0.34464680700760764, fmeasure=0.4540782894227583)), 'rougeLsum': AggregateScore(low=Score(precision=0.7087615578755443, recall=0.3065865811951284, fmeasure=0.41459636106423403), mid=Score(precision=0.7312493877207273, recall=0.3266553979292976, fmeasure=0.4348862280620006), high=Score(precision=0.7527788806473478, recall=0.34560461339036114, fmeasure=0.4536838896496699))}
# {'rouge1': 54.7, 'rouge2': 49.9, 'rougeL': 43.5, 'rougeLsum': 43.5}

# %% [markdown]
# ## Training third model

# %% [markdown]
# ### BART

# %%
#local path in the hyperparameters section of the training job
hyperparameters={
     'train_file':'/opt/ml/input/data/train/train_bcc_news_data.csv',
     'validation_file':'/opt/ml/input/data/validation/val_bcc_news_data.csv',
     'summary_column':'summary',
     'text_column':'text',
     'per_device_train_batch_size': 2,
     'per_device_eval_batch_size': 2,
     'model_name_or_path':'Josmar/BART_Finetuned_CNN_dailymail', # Pre-trained Pegasus model
     'do_train':True,
     'do_eval':True,
     'output_dir':'/opt/ml/model',
     'text_column': 'articles',
     'summary_column': 'summaries',
     'num_train_epochs': 6,
     'learning_rate': 5e-5,
     'seed': 7,
     'load_best_model_at_end':True,
     'max_source_length': 512,
     'report_to': 'wandb',    # ✍️
#      'run_name': 'hpt' 
     #'load_best_model_at_end':True
    # This is the maximum sequence length supported by Pegasus
 }

# create the Estimator
huggingface_estimator = HuggingFace(
    entry_point='run_summarization.py',
    source_dir='./examples/pytorch/summarization',
    git_config=git_config,
    instance_type='ml.g4dn.xlarge',
    instance_count=1,
    use_spot_instances=True,
    max_wait=3600,# max_wait should be equal to or greater than max_run in seconds
    max_run=1000,
    transformers_version='4.6',
    pytorch_version='1.7',
    py_version='py36',
    role=role,
    hyperparameters=hyperparameters,
    distribution=distribution,
)

# %%
huggingface_estimator.fit({'train':f's3://{bucket}/data_bbc/train_bcc_news_data.csv',
                           'validation':f's3://{bucket}/data_bbc/val_bcc_news_data.csv'})

# %% [markdown]
# ### Deploy the BART model
#
# #### the model is deployed using estimator.deploy()

# %%
# specifying BART model training job  
training_job_bart = 'huggingface-pytorch-training-2022-06-23-17-37-29-109'
#training_job = client.list_training_jobs()['TrainingJobSummaries'][0]['TrainingJobName']
model_data = sess.describe_training_job(training_job_bart)['ModelArtifacts']['S3ModelArtifacts']
model_data
# Out:
# 's3://sagemaker-ap-south-1-748276930737/huggingface-pytorch-training-2022-06-23-17-37-29-109/output/model.tar.gz'

# %%
from datasets import load_metric
metric = load_metric("rouge")

# %%
from sagemaker.huggingface import HuggingFaceModel

model_for_deployment = HuggingFaceModel(entry_point='inference.py',
                                        source_dir='./text-summarisation-project/inference_code',
                                        model_data=model_data,
                                        role=role,
                                        pytorch_version='1.7.1',
                                        py_version='py36',
                                        transformers_version='4.6.1',
                                        )

predictor_bart = model_for_deployment.deploy(initial_instance_count=1,
                                        instance_type='ml.g4dn.xlarge',
                                        serializer=sagemaker.serializers.JSONSerializer(),
                                        deserializer=sagemaker.deserializers.JSONDeserializer()
                                        )
# Out:
# ------!

# %%
candidate_summaries_bart = []

for i, text in enumerate(texts):
    if i % 100 == 0:
        print(i)
    data = {"inputs":text, "parameters_list":[{"min_length": 20, "max_length": 90}]}
    candidate_bart = predictor_bart.predict(data)
    candidate_summaries_bart.append(candidate_bart[0][0])
# Out:
# 0
# 100
# 200

# %%
def calc_rouge_scores(candidates, references):
    result = metric.compute(predictions=candidates, references=references, use_stemmer=True)
    print(result)
    result = {key: round(value.mid.fmeasure * 100, 1) for key, value in result.items()}
    return result

# %%
candidate_summaries[48]
# Out:
# "Shares in Google have fallen 6.7% after employees and early investors in the web search took advantage of the first chance to sell their holdings.Google's main service - its internet search - is free to users, so the firm makes much of its money from selling advertising space linked to the words for which its users search.However, analysts say they expected most shareholders would be holding back from selling all their shares immediately, as Google's"

# %%
ref_summaries[48]
# Out:
# "Google shares have risen since but fell $12.33 on Tuesday to close at $172.55.There were fears that the potential increase of shares in circulation from Tuesday would ease demand for stock.In one of the most closely-watched initial public offerings in stock market history, the US-based company sold 19.6 million shares at $85 each.Selling the shares could turn many of Google's workers into millionaires.However, analysts say they expected most shareholders would be holding back from selling all their shares immediately, as Google's good performance and future growth potential means demand will hold."

# %%
calc_rouge_scores(candidate_summaries, ref_summaries)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.9044161482683968, recall=0.422233239625049, fmeasure=0.5575135852964683), mid=Score(precision=0.9206823013128745, recall=0.44544000377711657, fmeasure=0.5780408497722369), high=Score(precision=0.9346380796492673, recall=0.4700915091147589, fmeasure=0.600053513980602)), 'rouge2': AggregateScore(low=Score(precision=0.8332231126292956, recall=0.38658249776041365, fmeasure=0.5103239769100156), mid=Score(precision=0.8566008027453814, recall=0.4097900872526817, fmeasure=0.5337370442576042), high=Score(precision=0.8784102887789129, recall=0.4335827285682283, fmeasure=0.5555461446371837)), 'rougeL': AggregateScore(low=Score(precision=0.7195111072720574, recall=0.33887888109488523, fmeasure=0.4462394502556551), mid=Score(precision=0.7406030081828598, recall=0.35668788017980546, fmeasure=0.46401889045587685), high=Score(precision=0.7605720195986367, recall=0.3794562424474862, fmeasure=0.48459943048970694)), 'rougeLsum': AggregateScore(low=Score(precision=0.720532179082072, recall=0.33953590193287453, fmeasure=0.4469292535190105), mid=Score(precision=0.7403863886393054, recall=0.35799733260235256, fmeasure=0.46486608716162214), high=Score(precision=0.7621011564260057, recall=0.3767035477916096, fmeasure=0.48351683507921756))}
# {'rouge1': 57.8, 'rouge2': 53.4, 'rougeL': 46.4, 'rougeLsum': 46.5}
